# %% [markdown]
# ## Synthetix Perpetual Futures PnL Report

# %%
import kwenta_pnl_report as report
report.futuresPnlReport()
# Out:
# <style  type="text/css" >
#     #T_51524686_e2b6_11ed_ad8b_54e1ad5db35frow0_col0 {
#             text-align:  right;
#         }    #T_51524686_e2b6_11ed_ad8b_54e1ad5db35frow0_col1 {
#             text-align:  right;
#         }</style><table id="T_51524686_e2b6_11ed_ad8b_54e1ad5db35f" ><caption>Total Market Debt and Pnl</caption><thead>    <tr>        <th class="col_heading level0 col0" >market_debt</th>        <th class="col_heading level0 col1" >net_pnl</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_51524686_e2b6_11ed_ad8b_54e1ad5db35frow0_col0" class="data row0 col0" >20,009,020</td>
#                         <td id="T_51524686_e2b6_11ed_ad8b_54e1ad5db35frow0_col1" class="data row0 col1" >-10,987,973</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_515a35d8_e2b6_11ed_a46f_54e1ad5db35frow0_col0 {
#             text-align:  right;
#         }    #T_515a35d8_e2b6_11ed_a46f_54e1ad5db35frow0_col1 {
# ...
